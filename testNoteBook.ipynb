# %% [markdown]
# # *Hello*
# ## My name is Olha

# %%
a = 3

# %%
print(a)
# Out:
# 3

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.sin(range(0,5)))
plt.title("title")
# Out:
# Text(0.5, 1.0, 'title')
